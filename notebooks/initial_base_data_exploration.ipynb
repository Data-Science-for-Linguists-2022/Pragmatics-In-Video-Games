# %% [markdown]
# # Initial Data Poke
# ***
# Alejandro Ciuba, alc307@pitt.edu
# ***
# ## Description
# Here is my initial poke of the data from the [video-game-text-corpora](https://github.com/hmi-utwente/video-game-text-corpora).
# NOTEBOOK!!!
# ***

# %%
# Necessary imports
import pandas as pd
import nltk
import re
import pickle as pkl

# I looked this up so everything is prettier
from IPython.display import display, HTML

CSS = """
.output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))

# Use display(dataframe) to show

# FILEPATH
filepath = "../private/vgt_corpora"

# %% [markdown]
# ***
# ## The Elder Scrolls Data:

# %%
# It is stored as a JSON file
elder_scrolls_df = pd.read_json(filepath + "/The Elder Scrolls/data/imperial_library_20200626.json")
display(elder_scrolls_df.head())

# To quote Ross Geller: "PIVOT, PIVOT, PIVOT"
elder_scrolls_df = elder_scrolls_df.transpose()
display(elder_scrolls_df.head())
# Out:
#             https://www.imperial-library.info/content/dying-mans-last-words  \
# game                                               [Morrowind]
# url          https://www.imperial-library.info/content/dyin...
# description  The  last words of a world-renowned archaeolog...
# author                                                   Indie
# title                                 A Dying Man's Last Words
#
#             https://www.imperial-library.info/content/fair-warning  \
# game                                               [Morrowind]
# url          https://www.imperial-library.info/content/fair...
# description  Fair warning to those who would enter the Grea...
# author                                                 Cumanya
# title                                           A Fair Warning
#
#             https://www.imperial-library.info/content/game-dinner  \
# game                             [Morrowind, Oblivion, Skyrim]
# url          https://www.imperial-library.info/content/game...
# description  A published letter from an anonymous spy about...
# author                                               Anonymous
# title                                         A Game at Dinner
#
#             https://www.imperial-library.info/content/hypothetical-treachery  \
# game                             [Morrowind, Oblivion, Skyrim]
# url          https://www.imperial-library.info/content/hypo...
# description  An amusing play about a bunch of backstabbing ...
# author                                           Anthil Morvir
# title                                 A Hypothetical Treachery
#
#              https://www.imperial-library.info/content/leaflet  \
# game                                               [Morrowind]
# url          https://www.imperial-library.info/content/leaflet
# description   Propaganda against the alchemist Aurane Frernis.
# author                                               Anonymous
# title                                                A Leaflet
#
#             https://www.imperial-library.info/content/less-rude-song  \
# game                        [Morrowind, Oblivion, TES: Online]
# url          https://www.imperial-library.info/content/less...
# description            And you thought Dark Elves were prudes.
# author                                               Anonymous
# title                                         A Less Rude Song
#
#             https://www.imperial-library.info/content/scrawled-note  \
# game                                               [Morrowind]
# url          https://www.imperial-library.info/content/scra...
# description                 Another "last words" type of note.
# author                                       Vulpriss Denisson
# title                                          A Scrawled Note
#
#             https://www.imperial-library.info/content/scroll-written-blood  \
# game                                               [Morrowind]
# url          https://www.imperial-library.info/content/scro...
# description  Yet another "last words" note. This note does ...
# author                                  Malaki the Lightfooted
# title                                A Scroll Written in Blood
#
#             https://www.imperial-library.info/content/short-history-morrowind  \
# game                                       [Morrowind, Skyrim]
# url          https://www.imperial-library.info/content/shor...
# description  A history book about Morrowind, mostly contain...
# author                                          Jeanette Sitte
# title                             A Short History of Morrowind
#
#             https://www.imperial-library.info/content/worn-and-weathered-note  \
# game                                               [Morrowind]
# url          https://www.imperial-library.info/content/worn...
# description  Beautiful and poetic prose. A tragedy for cert...
# author                                               Anonymous
# title                                A Worn and Weathered Note
#
#              ...  \
# game         ...
# url          ...
# description  ...
# author       ...
# title        ...
#
#             https://www.imperial-library.info/content/real-barenziah-part-5  \
# game                                              [Daggerfall]
# url          https://www.imperial-library.info/content/real...
# description  A must read! Very long. Pretty raunchy in some...
# author                             Plitinius Mero (uncredited)
# title                               The Real Barenziah, Part 5
#
#             https://www.imperial-library.info/content/real-barenziah-part-6  \
# game                                              [Daggerfall]
# url          https://www.imperial-library.info/content/real...
# description  A must read! Very long. Pretty raunchy in some...
# author                             Plitinius Mero (uncredited)
# title                               The Real Barenziah, Part 6
#
#             https://www.imperial-library.info/content/real-barenziah-part-7  \
# game                                              [Daggerfall]
# url          https://www.imperial-library.info/content/real...
# description  A must read! Very long. Pretty raunchy in some...
# author                             Plitinius Mero (uncredited)
# title                               The Real Barenziah, Part 7
#
#             https://www.imperial-library.info/content/real-barenziah-part-8  \
# game                                              [Daggerfall]
# url          https://www.imperial-library.info/content/real...
# description  A must read! Very long. Pretty raunchy in some...
# author                             Plitinius Mero (uncredited)
# title                               The Real Barenziah, Part 8
#
#             https://www.imperial-library.info/content/real-barenziah-part-9  \
# game                                              [Daggerfall]
# url          https://www.imperial-library.info/content/real...
# description  A must read! Very long. Pretty raunchy in some...
# author                             Plitinius Mero (uncredited)
# title                               The Real Barenziah, Part 9
#
#             https://www.imperial-library.info/content/real-barenziah-part-10  \
# game                                              [Daggerfall]
# url          https://www.imperial-library.info/content/real...
# description  A must read! Very long. Pretty raunchy in some...
# author                             Plitinius Mero (uncredited)
# title                              The Real Barenziah, Part 10
#
#             https://www.imperial-library.info/content/real-barenziah-part-11  \
# game                                              [Daggerfall]
# url          https://www.imperial-library.info/content/real...
# description  A must read! Very long. Pretty raunchy in some...
# author                             Plitinius Mero (uncredited)
# title                              The Real Barenziah, Part 11
#
#             https://www.imperial-library.info/content/real-barenziah-part-12  \
# game                                              [Daggerfall]
# url          https://www.imperial-library.info/content/real...
# description  A must read! Very long. Pretty raunchy in some...
# author                             Plitinius Mero (uncredited)
# title                              The Real Barenziah, Part 12
#
#             https://www.imperial-library.info/content/vampires-iliac-bay-part-i  \
# game                                              [Daggerfall]
# url          https://www.imperial-library.info/content/vamp...
# description  Like "On Lycantropy", it's a players' guide to...
# author                                               Anonymous
# title                        Vampires of the Iliac Bay, Part I
#
#             https://www.imperial-library.info/content/vampires-iliac-bay-part-ii
# game                                              [Daggerfall]
# url          https://www.imperial-library.info/content/vamp...
# description  Like "On Lycantropy", it's a players' guide to...
# author                                               Anonymous
# title                       Vampires of the Iliac Bay, Part II
#
# [5 rows x 5446 columns]
#                                                                              game  \
# https://www.imperial-library.info/content/dying...                    [Morrowind]
# https://www.imperial-library.info/content/fair-...                    [Morrowind]
# https://www.imperial-library.info/content/game-...  [Morrowind, Oblivion, Skyrim]
# https://www.imperial-library.info/content/hypot...  [Morrowind, Oblivion, Skyrim]
# https://www.imperial-library.info/content/leaflet                     [Morrowind]
#
#                                                                                                   url  \
# https://www.imperial-library.info/content/dying...  https://www.imperial-library.info/content/dyin...
# https://www.imperial-library.info/content/fair-...  https://www.imperial-library.info/content/fair...
# https://www.imperial-library.info/content/game-...  https://www.imperial-library.info/content/game...
# https://www.imperial-library.info/content/hypot...  https://www.imperial-library.info/content/hypo...
# https://www.imperial-library.info/content/leaflet   https://www.imperial-library.info/content/leaflet
#
#                                                                                           description  \
# https://www.imperial-library.info/content/dying...  The  last words of a world-renowned archaeolog...
# https://www.imperial-library.info/content/fair-...  Fair warning to those who would enter the Grea...
# https://www.imperial-library.info/content/game-...  A published letter from an anonymous spy about...
# https://www.imperial-library.info/content/hypot...  An amusing play about a bunch of backstabbing ...
# https://www.imperial-library.info/content/leaflet    Propaganda against the alchemist Aurane Frernis.
#
#                                                            author  \
# https://www.imperial-library.info/content/dying...          Indie
# https://www.imperial-library.info/content/fair-...        Cumanya
# https://www.imperial-library.info/content/game-...      Anonymous
# https://www.imperial-library.info/content/hypot...  Anthil Morvir
# https://www.imperial-library.info/content/leaflet       Anonymous
#
#                                                                        title  \
# https://www.imperial-library.info/content/dying...  A Dying Man's Last Words
# https://www.imperial-library.info/content/fair-...            A Fair Warning
# https://www.imperial-library.info/content/game-...          A Game at Dinner
# https://www.imperial-library.info/content/hypot...  A Hypothetical Treachery
# https://www.imperial-library.info/content/leaflet                  A Leaflet
#
#                                                                                                  text  \
# https://www.imperial-library.info/content/dying...  It's been many days since the collapse. I have...
# https://www.imperial-library.info/content/fair-...  This being an account of my limited journeys i...
# https://www.imperial-library.info/content/game-...  A GAME AT DINNER\nby\nAn Anonymous Spy\n\nForw...
# https://www.imperial-library.info/content/hypot...  A Hypothetical Treachery\nA One Act Play\nby\n...
# https://www.imperial-library.info/content/leaflet   BEWARE!!!!\nHAVE NO DEALINGS with AURANE FRERN...
#
#                                                    series
# https://www.imperial-library.info/content/dying...    NaN
# https://www.imperial-library.info/content/fair-...    NaN
# https://www.imperial-library.info/content/game-...    NaN
# https://www.imperial-library.info/content/hypot...    NaN
# https://www.imperial-library.info/content/leaflet     NaN

# %%
# Now let's get the names into their own column
elder_scrolls_df['title'] = [re.sub(r'https://www.imperial-library.info/content/', '', title) for title in elder_scrolls_df.index]

# Create a new DataFrame to get rid of the weirdness
elder_scrolls_df = elder_scrolls_df[['title', 'author', 'description', 'game', 'text', 'url']]
elder_scrolls_df = elder_scrolls_df.reset_index(drop=True)
display(elder_scrolls_df.head(20))
# Out:
#                         title                      author  \
# 0       dying-mans-last-words                       Indie
# 1                fair-warning                     Cumanya
# 2                 game-dinner                   Anonymous
# 3      hypothetical-treachery               Anthil Morvir
# 4                     leaflet                   Anonymous
# 5              less-rude-song                   Anonymous
# 6               scrawled-note           Vulpriss Denisson
# 7        scroll-written-blood      Malaki the Lightfooted
# 8     short-history-morrowind              Jeanette Sitte
# 9     worn-and-weathered-note                   Anonymous
# 10            abcs-barbarians                   Anonymous
# 11           aedra-and-daedra                   Anonymous
# 12   airship-captains-journal      Captain Roberto Jodoin
# 13  overview-gods-and-worship           Brother Hetchfeld
# 14       ancestors-and-dunmer                   Anonymous
# 15            annotated-anuad                   Anonymous
# 16          approaching-vivec                   Anonymous
# 17          arcana-restored-1               Wapna Neustra
# 18                arkay-enemy  King of Worms (apparently)
# 19             ashlands-hymns                   Anonymous
#
#                                           description  \
# 0   The  last words of a world-renowned archaeolog...
# 1   Fair warning to those who would enter the Grea...
# 2   A published letter from an anonymous spy about...
# 3   An amusing play about a bunch of backstabbing ...
# 4    Propaganda against the alchemist Aurane Frernis.
# 5             And you thought Dark Elves were prudes.
# 6                  Another "last words" type of note.
# 7   Yet another "last words" note. This note does ...
# 8   A history book about Morrowind, mostly contain...
# 9   Beautiful and poetic prose. A tragedy for cert...
# 10  Very nice book, strongly recommended for all b...
# 11  A brief overview of the differences between th...
# 12  A journal of ill-fated airship. It crashed in ...
# 13  The standard introductory religious work. Very...
# 14       Dunmer funerary rights and ancestor worship.
# 15  A theology book that discusses the creation of...
# 16  A book about one of Morrowind's gods, Vivec. I...
# 17  A guide to restoring arcane items in a mana fo...
# 18  King of Worms instruction to his people. Not s...
# 19                            An Ashlander love song.
#
#                                           game  \
# 0                                  [Morrowind]
# 1                                  [Morrowind]
# 2                [Morrowind, Oblivion, Skyrim]
# 3                [Morrowind, Oblivion, Skyrim]
# 4                                  [Morrowind]
# 5           [Morrowind, Oblivion, TES: Online]
# 6                                  [Morrowind]
# 7                                  [Morrowind]
# 8                          [Morrowind, Skyrim]
# 9                                  [Morrowind]
# 10                                 [Morrowind]
# 11            [Morrowind, Skyrim, TES: Online]
# 12                                 [Morrowind]
# 13  [Morrowind, Oblivion, Skyrim, TES: Online]
# 14                         [Morrowind, Skyrim]
# 15                                 [Morrowind]
# 16                                 [Morrowind]
# 17  [Morrowind, Oblivion, Skyrim, TES: Online]
# 18                         [Morrowind, Skyrim]
# 19                                 [Morrowind]
#
#                                                  text  \
# 0   It's been many days since the collapse. I have...
# 1   This being an account of my limited journeys i...
# 2   A GAME AT DINNER\nby\nAn Anonymous Spy\n\nForw...
# 3   A Hypothetical Treachery\nA One Act Play\nby\n...
# 4   BEWARE!!!!\nHAVE NO DEALINGS with AURANE FRERN...
# 5   They say\nThe Iliac Bay\nIs the place to barre...
# 6   Alas, Morty, my fallen companion, could not ma...
# 7   These will be the last words anyone ever hears...
# 8   Led by the legendary prophet Veloth, the ances...
# 9   I am forever swimming around, amidst this ocea...
# 10  \nA is for Atronach.\n\nB is for Bungler's Ban...
# 11  The designations of Gods, Demons, Aedra, and D...
# 12  Commander, Beauchamp Expedition\nEntry 1: Toda...
# 13  Editor's Note:\n\tBrother Hetchfeld is an Asso...
# 14  Ghosts Walk Among Them\nThe departed spirits o...
# 15  The first ones were brothers: Anu and Padomay....
# 16  Art Design Notes for the Warrior-Poet\nWho is ...
# 17  Arcana Restored:\n\tA Handbook\nby\n\tWapna Ne...
# 18  Hear me, children. Once I was a lowly man such...
# 19  [This is a volume of folk verses collected fro...
#
#                                                   url
# 0   https://www.imperial-library.info/content/dyin...
# 1   https://www.imperial-library.info/content/fair...
# 2   https://www.imperial-library.info/content/game...
# 3   https://www.imperial-library.info/content/hypo...
# 4   https://www.imperial-library.info/content/leaflet
# 5   https://www.imperial-library.info/content/less...
# 6   https://www.imperial-library.info/content/scra...
# 7   https://www.imperial-library.info/content/scro...
# 8   https://www.imperial-library.info/content/shor...
# 9   https://www.imperial-library.info/content/worn...
# 10  https://www.imperial-library.info/content/abcs...
# 11  https://www.imperial-library.info/content/aedr...
# 12  https://www.imperial-library.info/content/airs...
# 13  https://www.imperial-library.info/content/over...
# 14  https://www.imperial-library.info/content/ance...
# 15  https://www.imperial-library.info/content/anno...
# 16  https://www.imperial-library.info/content/appr...
# 17  https://www.imperial-library.info/content/arca...
# 18  https://www.imperial-library.info/content/arka...
# 19  https://www.imperial-library.info/content/ashl...

# %%
# Let's get some info about our cleaned data
print('===================== ELDER SCROLLS DATAFRAME =====================')
print(elder_scrolls_df.info())
print(elder_scrolls_df.shape)
# I COUNT ANONYMOUS ENTRIES AS 1
print("UNIQUE AUTHORS:", len(set(elder_scrolls_df['author'])))
print("UNIQUE ENTRIES", len(set(elder_scrolls_df['title']))) # Good, no dupes
# Out:
# ===================== ELDER SCROLLS DATAFRAME =====================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5446 entries, 0 to 5445
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        5446 non-null   object
#  1   author       5446 non-null   object
#  2   description  5446 non-null   object
#  3   game         5446 non-null   object
#  4   text         5446 non-null   object
#  5   url          5446 non-null   object
# dtypes: object(6)
# memory usage: 255.4+ KB
# None
# (5446, 6)
# UNIQUE AUTHORS: 2106
# UNIQUE ENTRIES 5446

# %%
# Let's make sure the list information was stored correctly
print(type(elder_scrolls_df.loc[0, 'game'])) # WE'RE GOOD!!!

# Let's get a master list of all the games featured
master_list = list()

for glist in elder_scrolls_df.loc[:, 'game']:
    for game in glist:
        if game not in master_list:
            master_list.append(game)
print(master_list)
print(len(master_list))
# Out:
# <class 'list'>
# ['Morrowind', 'Oblivion', 'Skyrim', 'TES: Online', 'Daggerfall', 'Arena']
# 6

# %%
# Now let's try to clean up the text data
print(elder_scrolls_df.loc[2, 'text'][:300]) # Looks like that's not an issue
# Out:
# A GAME AT DINNER
# by
# An Anonymous Spy
#
# Forward From The Publisher:
# The history behind this letter is almost as interesting and dark as the story it tells. The original letter to the mysterious Dhaunayne was copied and began circulating around the Ashlands of Vvardenfell a few months ago. In time, a p

# %%
# Let's make a word count section to our dataframe
# I decided to play it safe and use nltk.word_tokenize since, looking at the JSON, the data's been thoroughly kept already. 
# It's also nice to use an already established parsing-standard.
elder_scrolls_df['word_count'] = elder_scrolls_df.text.map(lambda x : len(nltk.word_tokenize(x)))

# Reorganize... again
elder_scrolls_df = elder_scrolls_df[['title', 'author', 'description', 'game', 'text', 'word_count', 'url']]
display(elder_scrolls_df.head(20))
# Out:
#                         title                      author  \
# 0       dying-mans-last-words                       Indie
# 1                fair-warning                     Cumanya
# 2                 game-dinner                   Anonymous
# 3      hypothetical-treachery               Anthil Morvir
# 4                     leaflet                   Anonymous
# 5              less-rude-song                   Anonymous
# 6               scrawled-note           Vulpriss Denisson
# 7        scroll-written-blood      Malaki the Lightfooted
# 8     short-history-morrowind              Jeanette Sitte
# 9     worn-and-weathered-note                   Anonymous
# 10            abcs-barbarians                   Anonymous
# 11           aedra-and-daedra                   Anonymous
# 12   airship-captains-journal      Captain Roberto Jodoin
# 13  overview-gods-and-worship           Brother Hetchfeld
# 14       ancestors-and-dunmer                   Anonymous
# 15            annotated-anuad                   Anonymous
# 16          approaching-vivec                   Anonymous
# 17          arcana-restored-1               Wapna Neustra
# 18                arkay-enemy  King of Worms (apparently)
# 19             ashlands-hymns                   Anonymous
#
#                                           description  \
# 0   The  last words of a world-renowned archaeolog...
# 1   Fair warning to those who would enter the Grea...
# 2   A published letter from an anonymous spy about...
# 3   An amusing play about a bunch of backstabbing ...
# 4    Propaganda against the alchemist Aurane Frernis.
# 5             And you thought Dark Elves were prudes.
# 6                  Another "last words" type of note.
# 7   Yet another "last words" note. This note does ...
# 8   A history book about Morrowind, mostly contain...
# 9   Beautiful and poetic prose. A tragedy for cert...
# 10  Very nice book, strongly recommended for all b...
# 11  A brief overview of the differences between th...
# 12  A journal of ill-fated airship. It crashed in ...
# 13  The standard introductory religious work. Very...
# 14       Dunmer funerary rights and ancestor worship.
# 15  A theology book that discusses the creation of...
# 16  A book about one of Morrowind's gods, Vivec. I...
# 17  A guide to restoring arcane items in a mana fo...
# 18  King of Worms instruction to his people. Not s...
# 19                            An Ashlander love song.
#
#                                           game  \
# 0                                  [Morrowind]
# 1                                  [Morrowind]
# 2                [Morrowind, Oblivion, Skyrim]
# 3                [Morrowind, Oblivion, Skyrim]
# 4                                  [Morrowind]
# 5           [Morrowind, Oblivion, TES: Online]
# 6                                  [Morrowind]
# 7                                  [Morrowind]
# 8                          [Morrowind, Skyrim]
# 9                                  [Morrowind]
# 10                                 [Morrowind]
# 11            [Morrowind, Skyrim, TES: Online]
# 12                                 [Morrowind]
# 13  [Morrowind, Oblivion, Skyrim, TES: Online]
# 14                         [Morrowind, Skyrim]
# 15                                 [Morrowind]
# 16                                 [Morrowind]
# 17  [Morrowind, Oblivion, Skyrim, TES: Online]
# 18                         [Morrowind, Skyrim]
# 19                                 [Morrowind]
#
#                                                  text  word_count  \
# 0   It's been many days since the collapse. I have...         394
# 1   This being an account of my limited journeys i...         228
# 2   A GAME AT DINNER\nby\nAn Anonymous Spy\n\nForw...        2705
# 3   A Hypothetical Treachery\nA One Act Play\nby\n...        2008
# 4   BEWARE!!!!\nHAVE NO DEALINGS with AURANE FRERN...         117
# 5   They say\nThe Iliac Bay\nIs the place to barre...         305
# 6   Alas, Morty, my fallen companion, could not ma...         170
# 7   These will be the last words anyone ever hears...         285
# 8   Led by the legendary prophet Veloth, the ances...         867
# 9   I am forever swimming around, amidst this ocea...         660
# 10  \nA is for Atronach.\n\nB is for Bungler's Ban...          17
# 11  The designations of Gods, Demons, Aedra, and D...         184
# 12  Commander, Beauchamp Expedition\nEntry 1: Toda...         671
# 13  Editor's Note:\n\tBrother Hetchfeld is an Asso...         745
# 14  Ghosts Walk Among Them\nThe departed spirits o...         746
# 15  The first ones were brothers: Anu and Padomay....         823
# 16  Art Design Notes for the Warrior-Poet\nWho is ...         488
# 17  Arcana Restored:\n\tA Handbook\nby\n\tWapna Ne...         331
# 18  Hear me, children. Once I was a lowly man such...         369
# 19  [This is a volume of folk verses collected fro...          73
#
#                                                   url
# 0   https://www.imperial-library.info/content/dyin...
# 1   https://www.imperial-library.info/content/fair...
# 2   https://www.imperial-library.info/content/game...
# 3   https://www.imperial-library.info/content/hypo...
# 4   https://www.imperial-library.info/content/leaflet
# 5   https://www.imperial-library.info/content/less...
# 6   https://www.imperial-library.info/content/scra...
# 7   https://www.imperial-library.info/content/scro...
# 8   https://www.imperial-library.info/content/shor...
# 9   https://www.imperial-library.info/content/worn...
# 10  https://www.imperial-library.info/content/abcs...
# 11  https://www.imperial-library.info/content/aedr...
# 12  https://www.imperial-library.info/content/airs...
# 13  https://www.imperial-library.info/content/over...
# 14  https://www.imperial-library.info/content/ance...
# 15  https://www.imperial-library.info/content/anno...
# 16  https://www.imperial-library.info/content/appr...
# 17  https://www.imperial-library.info/content/arca...
# 18  https://www.imperial-library.info/content/arka...
# 19  https://www.imperial-library.info/content/ashl...

# %%
# As a data sample, let's give the person any text entries where the text is <= 50 words long. I want the viewer to be more inclined to go to the original dataset
# Creating the sample DataFrame
elder_sample_df = elder_scrolls_df[elder_scrolls_df['word_count'] <= 50]
# Let's get some info about our sampled data
print('===================== ELDER SAMPLE DATAFRAME =====================')
print(elder_sample_df.info())
print(elder_sample_df.shape)
# I COUNT ANONYMOUS ENTRIES AS 1
print("UNIQUE AUTHORS:", len(set(elder_sample_df['author'])))
print("UNIQUE ENTRIES", len(set(elder_sample_df['title']))) # Good, no dupes

display(elder_sample_df.tail(20))
# Out:
# ===================== ELDER SAMPLE DATAFRAME =====================
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 620 entries, 10 to 5360
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        620 non-null    object
#  1   author       620 non-null    object
#  2   description  620 non-null    object
#  3   game         620 non-null    object
#  4   text         620 non-null    object
#  5   word_count   620 non-null    int64
#  6   url          620 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 38.8+ KB
# None
# (620, 7)
# UNIQUE AUTHORS: 156
# UNIQUE ENTRIES 620
#                                 title               author  \
# 5124            iron-wheel-precept-15            Anonymous
# 5125            iron-wheel-precept-21            Anonymous
# 5126            iron-wheel-precept-38            Anonymous
# 5130  ixtaxh-explorers-journal-page-4            Anonymous
# 5167     khunzar-ri-sayings-verse-one            Anonymous
# 5168     khunzar-ri-sayings-verse-two            Anonymous
# 5169   khunzar-ri-sayings-verse-three            Anonymous
# 5170    khunzar-ri-sayings-verse-four            Anonymous
# 5197       lady-cistern-velsas-theory            Anonymous
# 5255            rasirs-journal-page-8                Rasir
# 5268       secret-dwemer-origins-pt-2            Anonymous
# 5280          sumirils-book-passage-2            Anonymous
# 5284          sumirils-book-passage-6            Anonymous
# 5325           folly-isolation-part-7            Anonymous
# 5326           folly-isolation-part-8            Anonymous
# 5332       march-explored-chapter-iii  Fenlil the Wayfarer
# 5333        march-explored-chapter-vi  Fenlil the Wayfarer
# 5358          whisperers-song-verse-1            Anonymous
# 5359          whisperers-song-verse-2            Anonymous
# 5360          whisperers-song-verse-3            Anonymous
#
#                                             description           game  \
# 5124                                                     [TES: Online]
# 5125                                                     [TES: Online]
# 5126                                                     [TES: Online]
# 5130                                                     [TES: Online]
# 5167                                 Khajiiti aphorisms  [TES: Online]
# 5168                                 Khajiiti aphorisms  [TES: Online]
# 5169                                 Khajiiti aphorisms  [TES: Online]
# 5170                                 Khajiiti aphorisms  [TES: Online]
# 5197  A collection of theories regarding the statue ...  [TES: Online]
# 5255                                                     [TES: Online]
# 5268  These ramblings aledge that the Dwemer were ti...  [TES: Online]
# 5280                      A story of a boy and the land  [TES: Online]
# 5284                      A story of a boy and the land  [TES: Online]
# 5325  A satirical play lambasting the political fact...  [TES: Online]
# 5326  A satirical play lambasting the political fact...  [TES: Online]
# 5332                 Fragmented guide to Reaper's March  [TES: Online]
# 5333                 Fragmented guide to Reaper's March  [TES: Online]
# 5358                                                     [TES: Online]
# 5359                                                     [TES: Online]
# 5360                                                     [TES: Online]
#
#                                                    text  word_count  \
# 5124  Do not pity the lawbreaker.\n\tTheir fate is t...          22
# 5125  What of the unrepentant lawbreaker?\n\tWhen sh...          30
# 5126  The lawbreaker can deny truth,\n\tBut can neve...          24
# 5130  Something hidden in the walls. Writhing around...          36
# 5167  Khunzar-ri says\nWar is like the two Moons\nAl...          14
# 5168  Khunzar-ri says\nIn the spring, when\nMoon-sug...          35
# 5169  Khunzar-ri says\nIf Khajiit has much gold\nBut...          17
# 5170  Khunzar-ri says\nWalk silent and unseen\nTo yo...          28
# 5197  The statue is the Night Mother. Her right hand...          43
# 5255  I've prepared the rare mushroom.\nThe cure is ...          49
# 5268  It all makes perfect sense. Everything in here...          48
# 5280  Soon powerful people learned about the boy, an...          48
# 5284  And for once, Valenwood listened. And Ostion a...          50
# 5325  Herein, the scene where the Hero kills their m...          30
# 5326  Herein, find Act Three, where we have a speech...          29
# 5332  The March marks the eastern boundary of Valenw...          47
# 5333  … there's no truth to the rumors of dark cults...          47
# 5358  Do you fear me, dear intruder?\n\tWill you lis...          45
# 5359  For moons and more\n\tthe words I bore\n\twere...          27
# 5360  "But why?" they cry, inside their minds,\n\tun...          34
#
#                                                     url
# 5124  https://www.imperial-library.info/content/iron...
# 5125  https://www.imperial-library.info/content/iron...
# 5126  https://www.imperial-library.info/content/iron...
# 5130  https://www.imperial-library.info/content/ixta...
# 5167  https://www.imperial-library.info/content/khun...
# 5168  https://www.imperial-library.info/content/khun...
# 5169  https://www.imperial-library.info/content/khun...
# 5170  https://www.imperial-library.info/content/khun...
# 5197  https://www.imperial-library.info/content/lady...
# 5255  https://www.imperial-library.info/content/rasi...
# 5268  https://www.imperial-library.info/content/secr...
# 5280  https://www.imperial-library.info/content/sumi...
# 5284  https://www.imperial-library.info/content/sumi...
# 5325  https://www.imperial-library.info/content/foll...
# 5326  https://www.imperial-library.info/content/foll...
# 5332  https://www.imperial-library.info/content/marc...
# 5333  https://www.imperial-library.info/content/marc...
# 5358  https://www.imperial-library.info/content/whis...
# 5359  https://www.imperial-library.info/content/whis...
# 5360  https://www.imperial-library.info/content/whis...

# %%
# Finally, let's pickle both the main elder_scrolls_df DataFrame and elder_sample_df DataFrame and store them in the appropriate locations
# First the main one
elder_scrolls_df.to_pickle('../private/pickled_dfs/elder_scrolls.pkl')
elder_sample_df.to_pickle('../sample_data/elder_sample.pkl')

# %% [markdown]
# ***
# # Torchlight Data:
#
# **PLEASE NOTE** This data is stored in both a .csv and a .json. Please see [orignal documentation](https://github.com/hmi-utwente/video-game-text-corpora/tree/master/Torchlight%20II) for more information (no, the script doesn't work, I tried).

# %%
torchlight_df = pd.read_csv(filepath + '/Torchlight II/data/dataset_200630.csv')
display(torchlight_df.head())
# Out:
#         speaker                                               text dialogtype  \
# 0       Felicia  You seem weary - perhaps you are in need of a ...   complete
# 1  Bounty Board  BOUNTY!\nThe Sturmbeorn raiders are a threat t...      intro
# 2  Bounty Board  The Sturmbeorn have been conducting raids in n...     return
# 3  Bounty Board  The Empire thanks you for your valuable servic...   complete
# 4           NaN  Kill 10 Sturmbeorn in the Temple Steppes, then...    details
#
#          quest_displayname          quest_name                      questfile  \
# 0  The Adventure Continues  global_newgameplus  QUESTS/GLOBAL_NEWGAMEPLUS.DAT
# 1      Bounty: Sturmbeorn!   a1z1-bountyboard2   QUESTS/A1Z1-BOUNTYBOARD2.DAT
# 2      Bounty: Sturmbeorn!   a1z1-bountyboard2   QUESTS/A1Z1-BOUNTYBOARD2.DAT
# 3      Bounty: Sturmbeorn!   a1z1-bountyboard2   QUESTS/A1Z1-BOUNTYBOARD2.DAT
# 4      Bounty: Sturmbeorn!   a1z1-bountyboard2   QUESTS/A1Z1-BOUNTYBOARD2.DAT
#
#                speaker_unit  \
# 0  RETIREMENTCHARACTERQUEST
# 1               BOUNTYBOARD
# 2               BOUNTYBOARD
# 3               BOUNTYBOARD
# 4                       NaN
#
#                                             unitfile  \
# 0  MEDIA/UNITS/MONSTERS/NPC/RETIREMENTCHARACTERQU...
# 1   MEDIA/UNITS/MONSTERS/BOUNTYBOARD/BOUNTYBOARD.DAT
# 2   MEDIA/UNITS/MONSTERS/BOUNTYBOARD/BOUNTYBOARD.DAT
# 3   MEDIA/UNITS/MONSTERS/BOUNTYBOARD/BOUNTYBOARD.DAT
# 4                                                NaN
#
#                                             raw_text
# 0  You seem weary - perhaps you are in need of a ...
# 1  BOUNTY!\n\nThe Sturmbeorn raiders are a threat...
# 2  The Sturmbeorn have been conducting raids in n...
# 3  The Empire thanks you for your valuable servic...
# 4  Kill 10 |cFFA1D0FCSturmbeorn|u in the |cFFA1D0...

# %% [markdown]
# ***
# ## Star Wars: Knights of The Old Republic
